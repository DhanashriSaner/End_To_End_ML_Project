# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
warnings.filterwarnings("ignore")
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("exploratory_data.csv")
df.head()
# Out:
#    car_ID  symboling      CarName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...       130.0        mpfi
# 1        rwd          front       88.6  ...       130.0        mpfi
# 2        rwd          front       94.5  ...       152.0        mpfi
# 3        fwd          front       99.8  ...       109.0        mpfi
# 4        4wd          front       99.4  ...       136.0        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
# checking for feature values distribution and their value counts
cat_col = df.dtypes[df.dtypes==object].index

for col in cat_col:
    print(df[col].value_counts())
    print("==================================")
# Out:
# toyota         32
# nissan         18
# mazda          15
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          10
# dodge           9
# buick           8
# bmw             8
# plymouth        7
# audi            6
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: CarName, dtype: int64
# ...
# gas       182
# diesel     19
# Name: fueltype, dtype: int64
# ...
# std      165
# turbo     36
# Name: aspiration, dtype: int64
# ...
# four    113
# two      88
# Name: doornumber, dtype: int64
# ...
# sedan          95
# hatchback      68
# wagon          24
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# ...
# fwd    117
# rwd     75
# 4wd      9
# Name: drivewheel, dtype: int64
# ...
# front    198
# rear       3
# Name: enginelocation, dtype: int64
# ...
# ohc      144
# ohcf      15
# ohcv      13
# dohc      12
# ...

# %%
df.drop(['CarName'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8  ...       130.0        mpfi
# 1          front       88.6      168.8  ...       130.0        mpfi
# 2          front       94.5      171.2  ...       152.0        mpfi
# 3          front       99.8      176.6  ...       109.0        mpfi
# 4          front       99.4      176.6  ...       136.0        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %% [markdown]
# #### one hot encoding
#
# on features aspiration and doornumber

# %%
dummies = pd.get_dummies(df[['aspiration', 'doornumber']], drop_first=True)
df = pd.concat([df.drop(['aspiration', 'doornumber'],axis=1), dummies],axis=1)

# %%
df.head()
# Out:
#    car_ID  symboling fueltype      carbody drivewheel enginelocation  \
# 0       1          3      gas  convertible        rwd          front
# 1       2          3      gas  convertible        rwd          front
# 2       3          1      gas    hatchback        rwd          front
# 3       4          2      gas        sedan        fwd          front
# 4       5          2      gas        sedan        4wd          front
#
#    wheelbase  carlength  carwidth  carheight  ...  boreratio stroke  \
# 0       88.6      168.8      64.1       48.8  ...       3.47   2.68
# 1       88.6      168.8      64.1       48.8  ...       3.47   2.68
# 2       94.5      171.2      65.5       52.4  ...       2.68   3.47
# 3       99.8      176.6      66.2       54.3  ...       3.19   3.40
# 4       99.4      176.6      66.4       54.3  ...       3.19   3.40
#
#   compressionratio  horsepower peakrpm  citympg  highwaympg    price  \
# ...

# %%
# will removes rows which contains either hardtop or convertible or both as a carbody.
df = df[df["carbody"].str.contains("hardtop|convertible")  == False]

# %%
df.head(10)
# Out:
#     car_ID  symboling fueltype    carbody drivewheel enginelocation  \
# 2        3          1      gas  hatchback        rwd          front
# 3        4          2      gas      sedan        fwd          front
# 4        5          2      gas      sedan        4wd          front
# 5        6          2      gas      sedan        fwd          front
# 6        7          1      gas      sedan        fwd          front
# 7        9          1      gas      sedan        fwd          front
# 8       10          0      gas  hatchback        4wd          front
# 9       11          2      gas      sedan        rwd          front
# 10      12          0      gas      sedan        rwd          front
# 11      13          0      gas      sedan        rwd          front
#
#     wheelbase  carlength  carwidth  carheight  ...  boreratio stroke  \
# 2        94.5      171.2      65.5       52.4  ...       2.68   3.47
# 3        99.8      176.6      66.2       54.3  ...       3.19   3.40
# ...

# %%
# will removes rows which contains 4wd as a drivewheel value
df = df[df["drivewheel"].str.contains("4wd")  == False]

# %%
df.drivewheel.head(10)
# Out:
# 2     rwd
# 3     fwd
# 5     fwd
# 6     fwd
# 7     fwd
# 9     rwd
# 10    rwd
# 11    rwd
# 12    rwd
# 13    rwd
# Name: drivewheel, dtype: object

# %%
df.drivewheel.tail(10)
# Out:
# 191    rwd
# 192    rwd
# 193    rwd
# 194    rwd
# 195    rwd
# 196    rwd
# 197    rwd
# 198    rwd
# 199    rwd
# 200    rwd
# Name: drivewheel, dtype: object

# %%
df.drop(['enginelocation'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    car_ID  symboling fueltype    carbody drivewheel  wheelbase  carlength  \
# 2       3          1      gas  hatchback        rwd       94.5      171.2
# 3       4          2      gas      sedan        fwd       99.8      176.6
# 5       6          2      gas      sedan        fwd       99.8      177.3
# 6       7          1      gas      sedan        fwd      105.8      192.7
# 7       9          1      gas      sedan        fwd      105.8      192.7
#
#    carwidth  carheight  curbweight  ... boreratio stroke  compressionratio  \
# 2      65.5       52.4        2823  ...      2.68   3.47               9.0
# 3      66.2       54.3        2337  ...      3.19   3.40              10.0
# 5      66.3       53.1        2507  ...      3.19   3.40               8.5
# 6      71.4       55.7        2844  ...      3.19   3.40               8.5
# 7      71.4       55.9        3086  ...      3.13   3.40               8.3
#
# ...
